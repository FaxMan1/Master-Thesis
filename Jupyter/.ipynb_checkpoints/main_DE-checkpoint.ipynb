# %%
import sys
sys.path.append('../DE_PyCharm')
from DE import DE
from objective_functions import MSE
from data import create_3d_gauss_data
from data import create_simple_data
from visualizer import plot_2d_gauss, plot_simple_data

Xtrain, ytrain, Xtest, ytest = create_simple_data('sine', 300)

# %%
D = DE(objective_function=MSE, sizes=[1,8,1], pop_size=50, F=0.55, cr=0.85, 
        X=Xtrain, y=ytrain, Xtest=Xtest, ytest=ytest, type='regression')

best_agent, opt_agent = D.early_stop_training(patience=1000)
#best_agent = D.evolution(num_epochs=1001, verbose=True, print_epoch=100)
D.evaluate(plot_function=plot_simple_data, agent=opt_agent)
# Out:
# Test Cost falling 0.1454987225112547
# Test Cost falling 0.07191779774839359
# Test Cost falling 0.06558826327161614
# Test Cost falling 0.0645175999301527
# Test Cost falling 0.052247337514117
# Test Cost falling 0.04469661181065936
# Test Cost falling 0.03144445558017623
# Optimal number of iterations: 767
# Best error: 0.03144445558017623
# Error at stop: 0.03144445558017623
# Best agent is <Network.NeuralNetwork object at 0x1a20dcd400> with a train cost of 0.02992.
# And a test cost of 0.03144
